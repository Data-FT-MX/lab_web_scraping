# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')

html
soup
# Out:
# <!DOCTYPE html>
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
title = soup.select("h1.h3.lh-condensed")
title_text = [el.text for el in title]
title_text
clean_title=[title.strip() for title in title_text]
(clean_title)
# Out:
# ['Me No Dev',
#  'Emil Ernerfeldt',
#  'MichaIng',
#  'Tom Payne',
#  'Daishi Kato',
#  'Eliza Weisman',
#  'neverland',
#  'David Pedersen',
#  'PySimpleGUI',
#  'Ben Johnson',
#  'Shivam Mathur',
#  'Joe Chen',
#  'Sean McArthur',
#  'awkweb',
#  'Akin',
#  'Frederik Feichtmeier',
#  'Seth Michael Larson',
#  'Rich Harris',
#  'Rick',
#  'Tim Pope',
#  'Ben V. Brown',
#  'Anthony Rappa',
#  'Zoltan Kochan',
#  'Charles Kerr',
#  'Matthias Fey']

# %%
#your code
title_usuario = soup.select("p.f4.text-normal.mb-1")
title_text_usuario = [el.text for el in title_usuario]
clean_title2=[title.strip() for title in title_text_usuario]
clean_title2

#clean_title3= [clean_title[i] + clean_title2[i] for i in range(len(clean_title))]
# Out:
# ['me-no-dev',
#  'emilk',
#  'twpayne',
#  'dai-shi',
#  'hawkw',
#  'chenjiahan',
#  'davidpdrsn',
#  'PySimpleGUI',
#  'benbjohnson',
#  'shivammathur',
#  'unknwon',
#  'seanmonstar',
#  'tmm',
#  'akinsho',
#  'Feichtmeier',
#  'sethmlarson',
#  'Rich-Harris',
#  'LinuxSuRen',
#  'tpope',
#  'Ralim',
#  'rappasoft',
#  'zkochan',
#  'ckerr',
#  'rusty1s']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
title = soup.select("h1.h3.lh-condensed")
title_text = [el.text for el in title]
title_text
clean_title=[title.strip() for title in title_text]
(clean_title)
clean_title2=[title.replace("\n","") for title in clean_title]
clean_title3=[title.replace(" ","") for title in clean_title2]
clean_title3
# Out:
# ['OpenBB-finance/OpenBBTerminal',
#  'donnemartin/system-design-primer',
#  'Z4nzu/hackingtool',
#  'rdeepak2002/reddit-place-script-2022',
#  'orchest/orchest',
#  'sherlock-project/sherlock',
#  'Rapptz/discord.py',
#  'hpcaitech/ColossalAI',
#  'jumpserver/jumpserver',
#  'reznok/Spring4Shell-POC',
#  'jackfrued/Python-100-Days',
#  'projectdiscovery/nuclei-templates',
#  'soimort/you-get',
#  'lutris/lutris',
#  'ThioJoe/YT-Spammer-Purge',
#  'ultralytics/yolov5',
#  'open-mmlab/mmclassification',
#  'spotDL/spotify-downloader',
#  'wudududu/extract-video-ppt',
#  'ethereum/web3.py',
#  'kholia/OSX-KVM',
#  'lukas-blecher/LaTeX-OCR',
#  'freqtrade/freqtrade',
#  'home-assistant/core',
#  'freqtrade/freqtrade-strategies']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
image = soup.select('a.image img') 
image
image_text = ["https" + el["src"] for el in image]
image_text
# Out:
# ['https//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'https//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'https//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'https//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
python_links = soup.select('li a')
python_links = list(python_links)
python_links = [link["href"] for link in python_links]
python_links = [str(link) for link in python_links]
python_links_clean = [link for link in python_links if link.startswith("https") or link.startswith ("/")]
python_links_clean
format_links = []
for link in python_links_clean:
    if link.startswith("//"):
        format_links.append("https:" + link)
    
    elif link.startswith("/"):
        format_links.append("https://en.wikipedia.org/"+link)
    
    else:
        format_links.append(link)

format_links
# Out:
# ['https://en.wikipedia.org//wiki/Pythonidae',
#  'https://en.wikipedia.org//wiki/Python_(genus)',
#  'https://en.wikipedia.org//wiki/Python_(programming_language)',
#  'https://en.wikipedia.org//wiki/CMU_Common_Lisp',
#  'https://en.wikipedia.org//wiki/PERQ#PERQ_3',
#  'https://en.wikipedia.org//wiki/Python_of_Aenus',
#  'https://en.wikipedia.org//wiki/Python_(painter)',
#  'https://en.wikipedia.org//wiki/Python_of_Byzantium',
#  'https://en.wikipedia.org//wiki/Python_of_Catana',
#  'https://en.wikipedia.org//wiki/Python_Anghelo',
#  'https://en.wikipedia.org//wiki/Python_(Efteling)',
#  'https://en.wikipedia.org//wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  'https://en.wikipedia.org//wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  'https://en.wikipedia.org//wiki/Python_(automobile_maker)',
#  'https://en.wikipedia.org//wiki/Python_(Ford_prototype)',
#  'https://en.wikipedia.org//wiki/Python_(missile)',
#  'https://en.wikipedia.org//wiki/Python_(nuclear_primary)',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
titles = soup.select("div.usctitlechanged")
title_text = [el.text for el in titles]
#title_text
clean_title=[title.strip() for title in title_text]
clean_title2=[title.replace("*","") for title in clean_title]
clean_title3=[title.replace(" ","") for title in clean_title2]
print("Titulos que han cambiado: ",len(clean_title3))
clean_title3
# Out:
# Titulos que han cambiado:  10
# ['Title9-Arbitration٭',
#  'Title16-Conservation',
#  'Title18-CrimesandCriminalProcedure٭',
#  'Title20-Education',
#  'Title21-FoodandDrugs',
#  'Title31-MoneyandFinance٭',
#  "Title38-Veterans'Benefits٭",
#  'Title41-PublicContracts٭',
#  'Title42-ThePublicHealthandWelfare',
#  'Title48-TerritoriesandInsularPossessions']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
titles = soup.select("h3.title")
title_text = [el.text for el in titles]
clean_title=[title.strip() for title in title_text]
clean_title
# Out:
# ['YULAN ADONAY ARCHAGA CARIAS',
#  'EUGENE PALMER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'RAFAEL CARO-QUINTERO',
#  'OCTAVIANO JUAREZ-CORRO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
table= pd.read_html(html)
table[3]
data_frame=table[3]
data_frame2= data_frame[['Date & Time UTC','Latitude degrees','Longitude degrees','Last update [-]']]
data_frame2.columns=['Date & Time UTC','Latitude degrees','N-S','Longitude degrees','W-E','Region Name']
data_frame2 = data_frame2.head(20)
data_frame2
# Out:
#                        Date & Time UTC Latitude degrees N-S Longitude degrees  \
# 0       2022-04-03 23:03:56.005min ago            18.78   N            155.16
# 1       2022-04-03 22:58:42.210min ago            36.59   N             71.06
# 2       2022-04-03 22:50:52.118min ago            19.17   N            155.47
# 3       2022-04-03 22:47:34.021min ago             1.95   S             98.92
# 4       2022-04-03 22:22:55.646min ago            32.40   N            115.27
# 5       2022-04-03 22:17:02.052min ago             1.84   N             99.10
# 6   2022-04-03 22:00:03.91hr 09min ago            35.41   N             97.88
# 7   2022-04-03 21:59:22.01hr 09min ago             6.20   S            106.07
# 8   2022-04-03 21:54:18.11hr 14min ago            36.38   N             28.72
# 9   2022-04-03 21:48:33.01hr 20min ago             9.19   N            126.77
# 10  2022-04-03 21:48:20.01hr 20min ago            46.09   N             14.25
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://www.eventbrite.com.mx/d/online/hackathon/'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
titles = soup.select("div a strong")
title_text = [el.text for el in titles]
title2 = soup.select("small bdi") 
titles=[title.replace("<strong>","") for title in title_text]
titles=[title.replace("</strong>","") for title in title_text]
title2 = list(title2)
title2 = [str(tit) for tit in title2]
title2 = [(re.findall(r'\d+',tit)) for tit in title2]
title3=[]
string=""
for i in title2:
    string=""
    for j in range(len(i)):
        string=string+i[j]
    title3.append(string)
    
titlefinal=[]
for i in range(len(titles)):
    titlefinal.append(titles[i] + " " + title3[i])
    
titlefinal
# Out:
# ['English 6458000',
#  'Русский 1798000',
#  '日本語 1314000',
#  'Español 1755000',
#  'Deutsch 2667000',
#  'Français 2400000',
#  '中文 1256000',
#  'Italiano 1742000',
#  'Português 1085000',
#  'Polski 1512000']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
titles = soup.select("h3 a.govuk-link")
title_text = [el.text for el in titles]
title_text
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,'lxml')
table= pd.read_html(html)
idiomas = table[3].head(10)
idiomas
# Out:
#   Rank                  Language Nativespeakersin millions2007 (2010)  \
# 0    1  Mandarin (entire branch)                            935 (955)
# 1    2                   Spanish                            390 (405)
# 2    3                   English                            365 (360)
# 3    4                  Hindi[b]                            295 (310)
# 4    5                    Arabic                            280 (295)
# 5    6                Portuguese                            205 (215)
# 6    7                   Bengali                            200 (205)
# 7    8                   Russian                            160 (155)
# 8    9                  Japanese                            125 (125)
# 9   10                   Punjabi                             95 (100)
#
#   Percentageof worldpopulation(2007)
# 0                              14.1%
# 1                              5.85%
# 2                              5.52%
# 3                              4.46%
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
